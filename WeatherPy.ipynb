# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['upernavik',
#  'khash',
#  'quelimane',
#  'kaitangata',
#  'namatanai',
#  'abu dhabi',
#  'hermanus',
#  'hobart',
#  'taolanaro',
#  'umea',
#  'ilulissat',
#  'hasaki',
#  'rogaska slatina',
#  'terrace',
#  'tacna',
#  'ushuaia',
#  'chapais',
#  'zabid',
#  'kahului',
#  'new norfolk',
#  'kapaa',
#  'wiarton',
#  'orocue',
#  'lebu',
#  'rikitea',
#  'sao joao da barra',
#  'iqaluit',
#  'barrow',
#  'almaznyy',
#  'ulladulla',
#  'atuona',
#  'hithadhoo',
#  'cape town',
#  'hilo',
#  'barentsburg',
#  'naze',
#  'tuktoyaktuk',
#  'fredonia',
#  'slave lake',
#  'mehamn',
#  'leningradskiy',
#  'kasungu',
#  'torbay',
#  'tura',
#  'ialibu',
#  'acapulco',
#  'pisco',
#  'dikson',
#  'ishigaki',
#  'illoqqortoormiut',
#  'arraial do cabo',
#  'isla vista',
#  'busselton',
#  'thompson',
#  'takoradi',
#  'katsuura',
#  'puerto ayora',
#  'yellowknife',
#  'sur',
#  'jamestown',
#  'vaini',
#  'lagoa',
#  'temaraia',
#  'north bend',
#  'talnakh',
#  'tucuma',
#  'urdoma',
#  'avarua',
#  'warqla',
#  'henties bay',
#  'kasama',
#  'butaritari',
#  'ucluelet',
#  'saskylakh',
#  'haifa',
#  'port alfred',
#  'polyarnyy',
#  'atar',
#  'georgetown',
#  'camana',
#  'kholtoson',
#  'punta arenas',
#  'areosa',
#  'bend',
#  'trairi',
#  'faanui',
#  'odemis',
#  'canelones',
#  'alice springs',
#  'nouadhibou',
#  'at-bashi',
#  'amderma',
#  'hlotse',
#  'qaanaaq',
#  'port elizabeth',
#  'coquimbo',
#  'elk city',
#  'ribeira grande',
#  'tezu',
#  'bako',
#  'jalu',
#  'east london',
#  'ulaanbaatar',
#  'howard springs',
#  'hambantota',
#  'presidencia roque saenz pena',
#  'belaya kholunitsa',
#  'esperance',
#  'bluff',
#  'albany',
#  'mataura',
#  'ambon',
#  'saint george',
#  'primalkinskoye',
#  'da nang',
#  'lata',
#  'alamogordo',
#  'dakoro',
#  'namibe',
#  'grindavik',
#  'pevek',
#  'narsaq',
#  'cherskiy',
#  'guerrero negro',
#  'vangaindrano',
#  'aleppo',
#  'kushima',
#  'kalabo',
#  'pedregulho',
#  'necochea',
#  'provideniya',
#  'wahran',
#  'gwadar',
#  'banjar',
#  'nizhneyansk',
#  'noyabrsk',
#  'gasa',
#  'norman wells',
#  'carnarvon',
#  'baruun-urt',
#  'clyde river',
#  'erzin',
#  'amapa',
#  'spearfish',
#  'kampar',
#  'tirumullaivasal',
#  'salalah',
#  'kavaratti',
#  'pacific grove',
#  'autlan',
#  'longyearbyen',
#  'tiksi',
#  'teguldet',
#  'goya',
#  'saint-pierre',
#  'kavieng',
#  'praia',
#  'byron bay',
#  'chokurdakh',
#  'khani',
#  'sri aman',
#  'kodiak',
#  'mongo',
#  'salta',
#  'ormara',
#  'boa vista',
#  'cordele',
#  'tavda',
#  'wattegama',
#  'centralia',
#  'ambilobe',
#  'muravlenko',
#  'buhovo',
#  'airai',
#  'brae',
#  'vostok',
#  'kandi',
#  'bredasdorp',
#  'beloha',
#  'port lincoln',
#  'cidreira',
#  'livingston',
#  'sibolga',
#  'springbok',
#  'zhelyabovka',
#  'auki',
#  'deputatskiy',
#  'san andres',
#  'tessalit',
#  'balimo',
#  'boyolangu',
#  'wajir',
#  'kamenskoye',
#  'chuy',
#  'aasiaat',
#  'piacabucu',
#  'suntar',
#  'sao miguel do araguaia',
#  'mys shmidta',
#  'maragogi',
#  'constitucion',
#  'grimma',
#  'chase',
#  'krasnoselkup',
#  'walvis bay',
#  'saint-philippe',
#  'vaitupu',
#  'constantine',
#  'ancud',
#  'saldanha',
#  'comodoro rivadavia',
#  'killybegs',
#  'malanje',
#  'pangnirtung',
#  'taoudenni',
#  'severo-kurilsk',
#  'wanning',
#  'port hardy',
#  'kargil',
#  'bilma',
#  'khatanga',
#  'otane',
#  'biltine',
#  'bukama',
#  'vestmannaeyjar',
#  'bilibino',
#  'tasiilaq',
#  'plettenberg bay',
#  'skibbereen',
#  'castro',
#  'victoria',
#  'belushya guba',
#  'puerto carreno',
#  'fasa',
#  'nome',
#  'palabuhanratu',
#  'lompoc',
#  'sorvag',
#  'kajaani',
#  'mossendjo',
#  'svetlaya',
#  'san ignacio',
#  'general pico',
#  'oranjemund',
#  'jinchengjiang',
#  'fortuna',
#  'zavitinsk',
#  'ostrovnoy',
#  'neepawa',
#  'abu jubayhah',
#  'keti bandar',
#  'mananara',
#  'shimoda',
#  'batagay-alyta',
#  'borogontsy',
#  'aksu',
#  'kazalinsk',
#  'nurobod',
#  'zavodouspenskoye',
#  'saint-augustin',
#  'nemuro',
#  'srednekolymsk',
#  'itaberai',
#  'nikolskoye',
#  'bethel',
#  'ekhabi',
#  'franklin',
#  'shagamu',
#  'molina',
#  'mount isa',
#  'koumac',
#  'iwaki',
#  'tayu',
#  'codrington',
#  'krasnovishersk',
#  'adeje',
#  'aykino',
#  'raudeberg',
#  'touros',
#  'bocas del toro',
#  'hovd',
#  'robertsport',
#  'sao filipe',
#  'fort morgan',
#  'salekhard',
#  'west wendover',
#  'zhuanghe',
#  'itarema',
#  'fort saint john',
#  'lodwar',
#  'paita',
#  'alofi',
#  'macamic',
#  'emerald',
#  'geraldton',
#  'kruisfontein',
#  'mandalgovi',
#  'chicama',
#  'port macquarie',
#  'luderitz',
#  'petropavlovsk-kamchatskiy',
#  'bandarbeyla',
#  'guymon',
#  'nizwa',
#  'ocos',
#  'komsomolskiy',
#  'bubaque',
#  'lufilufi',
#  'hamina',
#  'vila franca do campo',
#  'nikel',
#  'raisen',
#  'simao',
#  'san patricio',
#  'chara',
#  'chitral',
#  'berlevag',
#  'dromolaxia',
#  'marcona',
#  'egvekinot',
#  'mar del plata',
#  'samusu',
#  'macaboboni',
#  'two rivers',
#  'maniitsoq',
#  'paamiut',
#  'sovetskiy',
#  'vao',
#  'nanortalik',
#  'hegang',
#  'yishui',
#  'port augusta',
#  'lakatoro',
#  'placer',
#  'rio grande',
#  'songadh',
#  'santa lucia',
#  'domna',
#  'luanda',
#  'erfurt',
#  'cabo san lucas',
#  'havoysund',
#  'parana',
#  'caravelas',
#  'aklavik',
#  'sawtell',
#  'bolungarvik',
#  'mahebourg',
#  'puerto del rosario',
#  'avera',
#  'estevan',
#  'nam phong',
#  'hamilton',
#  'unnao',
#  'tir pol',
#  'nyaunglebin',
#  'dzerzhinskoye',
#  'malwan',
#  'krasnyy yar',
#  'serenje',
#  'sataua',
#  'nabire',
#  'pudozh',
#  'nijar',
#  'sharjah',
#  'joshimath',
#  'shahrud',
#  'bengkulu',
#  'vila velha',
#  'olafsvik',
#  'keffi',
#  'half moon bay',
#  'bambous virieux',
#  'whitehorse',
#  'bur gabo',
#  'kuytun',
#  'lloydminster',
#  'alekseyevka',
#  'anqing',
#  'safaqis',
#  'beira',
#  'middleton',
#  'canarana',
#  'charlestown',
#  'sal rei',
#  'sorland',
#  'port-gentil',
#  'pasni',
#  'rockingham',
#  'boende',
#  'vegreville',
#  'mizan teferi',
#  'muhos',
#  'buala',
#  'tocopilla',
#  'port pirie',
#  'curaca',
#  'souillac',
#  'tomatlan',
#  'sentyabrskiy',
#  'ossora',
#  'omutinskoye',
#  'erenhot',
#  'vardo',
#  'labuhan',
#  'liusha',
#  'valparaiso',
#  'teberda',
#  'yeniseysk',
#  'cairns',
#  'beruwala',
#  'stromness',
#  'arvika',
#  'hluti',
#  'los llanos de aridane',
#  'black forest',
#  'bud',
#  'hibbing',
#  'arman',
#  'okato',
#  'cochabamba',
#  'hualmay',
#  'flinders',
#  'harper',
#  'rawlins',
#  'grand river south east',
#  'evanston',
#  'sumbawa',
#  'abramovka',
#  'huajuapan',
#  'sitka',
#  'langfang',
#  'isangel',
#  'chimala',
#  'whitewater',
#  'moyamba',
#  'mason city',
#  'belmonte',
#  'saint-georges',
#  'grafton',
#  'huilong',
#  'caxito',
#  'winneba',
#  'yuncheng',
#  'haines junction',
#  'sunyani',
#  'san cristobal',
#  'ngukurr',
#  'kita',
#  'sholokhove',
#  'kichera',
#  'opuwo',
#  'salvador',
#  'sao desiderio',
#  'tabukiniberu',
#  'clarence town',
#  'quatre cocos',
#  'townsville',
#  'xiaoweizhai',
#  'tambacounda',
#  'rawson',
#  'bonthe',
#  'zhigansk',
#  'port hedland',
#  'puerto penasco',
#  'yazman',
#  'falealupo',
#  'visby',
#  'mareeba',
#  'bella union',
#  'changanacheri',
#  'tumannyy',
#  'tiassale',
#  'cohoes',
#  'tabiauea',
#  'progreso',
#  'iracoubo',
#  'mount gambier',
#  'sikea',
#  'yenagoa',
#  'payson',
#  'sakakah',
#  'lebedinyy',
#  'tigre',
#  'songea',
#  'nhulunbuy',
#  'nioro',
#  'ust-tsilma',
#  'jiuquan',
#  'eenhana',
#  'meulaboh',
#  'nanae',
#  'sumkino',
#  'ahipara',
#  'batsfjord',
#  'svetlyy',
#  'eunice',
#  'chimoio',
#  'roma',
#  'ponta do sol',
#  'suluq',
#  'mildura',
#  'bonavista',
#  'klaksvik',
#  'lorengau',
#  'gizo',
#  'garowe',
#  'ferme-neuve',
#  'vestmanna',
#  'movilita',
#  'sudzha',
#  'aransas pass',
#  'aklera',
#  'ibra',
#  'maceio',
#  'tubuala',
#  'houston',
#  'fukue',
#  'tibiri',
#  'shinshiro',
#  'saleaula',
#  'along',
#  'reconquista',
#  'bridlington',
#  'nicolas bravo',
#  'sabile',
#  'kainantu',
#  'grand gaube',
#  'lamar',
#  'yerbogachen',
#  'kemijarvi',
#  'elliot',
#  'tommot',
#  'svelgen',
#  'sungairaya',
#  'xingyi',
#  'derbent',
#  'port hawkesbury',
#  'itoman',
#  'sabha',
#  'stettler',
#  'omboue',
#  'grajau',
#  'broken hill',
#  'acarau',
#  'yantarnyy',
#  'isabela',
#  'kalaleh',
#  'eyl',
#  'czarnkow',
#  'mogadishu',
#  'the pas',
#  'san quintin',
#  'cortez',
#  'muzquiz',
#  'tual',
#  'baryatino',
#  'chone',
#  'kendrapara',
#  'khonuu',
#  'san carlos de bariloche',
#  'ghanzi',
#  'shetpe',
#  'manggar',
#  'pangody',
#  'martinho campos',
#  'kurduvadi',
#  'altamira',
#  'moindou',
#  'halvad',
#  'pouso alegre',
#  'konce',
#  'pochutla',
#  'jujuy',
#  'yantal',
#  'laguna',
#  'cassilandia',
#  'usinsk',
#  'pitimbu',
#  'karkaralinsk',
#  'kostomuksha',
#  'tsihombe',
#  'rieti',
#  'gamba',
#  'beni',
#  'healdsburg',
#  'baykit',
#  'poum',
#  'clermont',
#  'oil city',
#  'noshiro',
#  'qatana',
#  'bendigo',
#  'awjilah',
#  'ust-kamchatsk',
#  'ola',
#  'slantsy',
#  'qui nhon',
#  'okhotsk',
#  'batatais',
#  'lavrentiya',
#  'aflu',
#  'sao sebastiao do passe',
#  'saint-francois',
#  'tignere',
#  'mandurah',
#  'dwarka',
#  'san policarpo',
#  'dali',
#  'lydenburg',
#  'horasan',
#  'hendijan']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ba073198bfc73973ae3f269d5ba2e7fb

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ba073198bfc73973ae3f269d5ba2e7fb&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":61.84,"feels_like":57.4,"temp_min":59,"temp_max":64,"pressure":1029,"humidity":70},"visibility":10000,"wind":{"speed":8.99,"deg":290,"gust":18.01},"clouds":{"all":0},"dt":1604589257,"sys":{"type":3,"id":2013408,"country":"US","sunrise":1604575388,"sunset":1604611953},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 61.84,
#   'feels_like': 57.4,
#   'temp_min': 59,
#   'temp_max': 64,
#   'pressure': 1029,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 8.99, 'deg': 290, 'gust': 18.01},
#  'clouds': {'all': 0},
#  'dt': 1604589257,
#  'sys': {'type': 3,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1604575388,
#   'sunset': 1604611953},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 61.84,
#   'feels_like': 57.4,
#   'temp_min': 59,
#   'temp_max': 64,
#   'pressure': 1029,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 8.99, 'deg': 290, 'gust': 18.01},
#  'clouds': {'all': 0},
#  'dt': 1604589257,
#  'sys': {'type': 3,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1604575388,
#   'sunset': 1604611953},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 3,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1604575388,
#  'sunset': 1604611953}

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 64 70 0 8.99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 11, 5, 15, 14, 17)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-11-05 15:14:17'

# %%
city_data = []

# %%
city_data
# Out:
# []

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | khash
# Processing Record 3 of Set 1 | quelimane
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | namatanai
# Processing Record 6 of Set 1 | abu dhabi
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | umea
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | hasaki
# Processing Record 13 of Set 1 | rogaska slatina
# Processing Record 14 of Set 1 | terrace
# Processing Record 15 of Set 1 | tacna
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | chapais
# Processing Record 18 of Set 1 | zabid
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | wiarton
# Processing Record 23 of Set 1 | orocue
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | sao joao da barra
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | almaznyy
# Processing Record 30 of Set 1 | ulladulla
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | fredonia
# Processing Record 39 of Set 1 | slave lake
# Processing Record 40 of Set 1 | mehamn
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | kasungu
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | ialibu
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | ishigaki
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | isla vista
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | takoradi
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | sur
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | lagoa
# Processing Record 13 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 2 | north bend
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | tucuma
# Processing Record 17 of Set 2 | urdoma
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 2 | henties bay
# Processing Record 21 of Set 2 | kasama
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | ucluelet
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | haifa
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | polyarnyy
# Processing Record 28 of Set 2 | atar
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | camana
# Processing Record 31 of Set 2 | kholtoson
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | areosa
# Processing Record 34 of Set 2 | bend
# Processing Record 35 of Set 2 | trairi
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | odemis
# City not found. Skipping...
# Processing Record 38 of Set 2 | canelones
# Processing Record 39 of Set 2 | alice springs
# Processing Record 40 of Set 2 | nouadhibou
# Processing Record 41 of Set 2 | at-bashi
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | hlotse
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | elk city
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | tezu
# Processing Record 50 of Set 2 | bako
# Processing Record 1 of Set 3 | jalu
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | ulaanbaatar
# Processing Record 4 of Set 3 | howard springs
# Processing Record 5 of Set 3 | hambantota
# Processing Record 6 of Set 3 | presidencia roque saenz pena
# Processing Record 7 of Set 3 | belaya kholunitsa
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | ambon
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | primalkinskoye
# Processing Record 15 of Set 3 | da nang
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | alamogordo
# Processing Record 18 of Set 3 | dakoro
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | grindavik
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | vangaindrano
# Processing Record 26 of Set 3 | aleppo
# Processing Record 27 of Set 3 | kushima
# Processing Record 28 of Set 3 | kalabo
# Processing Record 29 of Set 3 | pedregulho
# Processing Record 30 of Set 3 | necochea
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 3 | gwadar
# Processing Record 34 of Set 3 | banjar
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | noyabrsk
# Processing Record 37 of Set 3 | gasa
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | baruun-urt
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | erzin
# Processing Record 43 of Set 3 | amapa
# Processing Record 44 of Set 3 | spearfish
# Processing Record 45 of Set 3 | kampar
# Processing Record 46 of Set 3 | tirumullaivasal
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | pacific grove
# Processing Record 50 of Set 3 | autlan
# City not found. Skipping...
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | teguldet
# Processing Record 4 of Set 4 | goya
# Processing Record 5 of Set 4 | saint-pierre
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | byron bay
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | khani
# Processing Record 11 of Set 4 | sri aman
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | mongo
# Processing Record 14 of Set 4 | salta
# Processing Record 15 of Set 4 | ormara
# Processing Record 16 of Set 4 | boa vista
# Processing Record 17 of Set 4 | cordele
# Processing Record 18 of Set 4 | tavda
# Processing Record 19 of Set 4 | wattegama
# Processing Record 20 of Set 4 | centralia
# Processing Record 21 of Set 4 | ambilobe
# Processing Record 22 of Set 4 | muravlenko
# Processing Record 23 of Set 4 | buhovo
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | brae
# Processing Record 26 of Set 4 | vostok
# Processing Record 27 of Set 4 | kandi
# Processing Record 28 of Set 4 | bredasdorp
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | livingston
# Processing Record 33 of Set 4 | sibolga
# Processing Record 34 of Set 4 | springbok
# Processing Record 35 of Set 4 | zhelyabovka
# Processing Record 36 of Set 4 | auki
# Processing Record 37 of Set 4 | deputatskiy
# Processing Record 38 of Set 4 | san andres
# Processing Record 39 of Set 4 | tessalit
# Processing Record 40 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 41 of Set 4 | boyolangu
# Processing Record 42 of Set 4 | wajir
# Processing Record 43 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | aasiaat
# Processing Record 46 of Set 4 | piacabucu
# Processing Record 47 of Set 4 | suntar
# Processing Record 48 of Set 4 | sao miguel do araguaia
# Processing Record 49 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 4 | maragogi
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | grimma
# Processing Record 3 of Set 5 | chase
# Processing Record 4 of Set 5 | krasnoselkup
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | constantine
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | comodoro rivadavia
# Processing Record 12 of Set 5 | killybegs
# Processing Record 13 of Set 5 | malanje
# Processing Record 14 of Set 5 | pangnirtung
# Processing Record 15 of Set 5 | taoudenni
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | wanning
# Processing Record 18 of Set 5 | port hardy
# Processing Record 19 of Set 5 | kargil
# Processing Record 20 of Set 5 | bilma
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | otane
# Processing Record 23 of Set 5 | biltine
# Processing Record 24 of Set 5 | bukama
# Processing Record 25 of Set 5 | vestmannaeyjar
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | tasiilaq
# Processing Record 28 of Set 5 | plettenberg bay
# Processing Record 29 of Set 5 | skibbereen
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | puerto carreno
# Processing Record 34 of Set 5 | fasa
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 5 | kajaani
# Processing Record 40 of Set 5 | mossendjo
# Processing Record 41 of Set 5 | svetlaya
# Processing Record 42 of Set 5 | san ignacio
# Processing Record 43 of Set 5 | general pico
# Processing Record 44 of Set 5 | oranjemund
# Processing Record 45 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | zavitinsk
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | neepawa
# Processing Record 50 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 6 | keti bandar
# Processing Record 2 of Set 6 | mananara
# Processing Record 3 of Set 6 | shimoda
# Processing Record 4 of Set 6 | batagay-alyta
# Processing Record 5 of Set 6 | borogontsy
# Processing Record 6 of Set 6 | aksu
# Processing Record 7 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 6 | nurobod
# Processing Record 9 of Set 6 | zavodouspenskoye
# Processing Record 10 of Set 6 | saint-augustin
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | srednekolymsk
# Processing Record 13 of Set 6 | itaberai
# Processing Record 14 of Set 6 | nikolskoye
# Processing Record 15 of Set 6 | bethel
# Processing Record 16 of Set 6 | ekhabi
# Processing Record 17 of Set 6 | franklin
# Processing Record 18 of Set 6 | shagamu
# Processing Record 19 of Set 6 | molina
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | koumac
# Processing Record 22 of Set 6 | iwaki
# Processing Record 23 of Set 6 | tayu
# Processing Record 24 of Set 6 | codrington
# Processing Record 25 of Set 6 | krasnovishersk
# Processing Record 26 of Set 6 | adeje
# Processing Record 27 of Set 6 | aykino
# Processing Record 28 of Set 6 | raudeberg
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | bocas del toro
# Processing Record 31 of Set 6 | hovd
# Processing Record 32 of Set 6 | robertsport
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | fort morgan
# Processing Record 35 of Set 6 | salekhard
# Processing Record 36 of Set 6 | west wendover
# Processing Record 37 of Set 6 | zhuanghe
# Processing Record 38 of Set 6 | itarema
# Processing Record 39 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 6 | lodwar
# Processing Record 41 of Set 6 | paita
# Processing Record 42 of Set 6 | alofi
# Processing Record 43 of Set 6 | macamic
# Processing Record 44 of Set 6 | emerald
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | kruisfontein
# Processing Record 47 of Set 6 | mandalgovi
# Processing Record 48 of Set 6 | chicama
# Processing Record 49 of Set 6 | port macquarie
# Processing Record 50 of Set 6 | luderitz
# Processing Record 1 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | guymon
# Processing Record 4 of Set 7 | nizwa
# Processing Record 5 of Set 7 | ocos
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | lufilufi
# Processing Record 9 of Set 7 | hamina
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | nikel
# Processing Record 12 of Set 7 | raisen
# Processing Record 13 of Set 7 | simao
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | chara
# Processing Record 16 of Set 7 | chitral
# Processing Record 17 of Set 7 | berlevag
# Processing Record 18 of Set 7 | dromolaxia
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | egvekinot
# Processing Record 21 of Set 7 | mar del plata
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 7 | two rivers
# Processing Record 25 of Set 7 | maniitsoq
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | sovetskiy
# Processing Record 28 of Set 7 | vao
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | hegang
# Processing Record 31 of Set 7 | yishui
# Processing Record 32 of Set 7 | port augusta
# Processing Record 33 of Set 7 | lakatoro
# Processing Record 34 of Set 7 | placer
# Processing Record 35 of Set 7 | rio grande
# Processing Record 36 of Set 7 | songadh
# Processing Record 37 of Set 7 | santa lucia
# Processing Record 38 of Set 7 | domna
# Processing Record 39 of Set 7 | luanda
# Processing Record 40 of Set 7 | erfurt
# Processing Record 41 of Set 7 | cabo san lucas
# Processing Record 42 of Set 7 | havoysund
# Processing Record 43 of Set 7 | parana
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | aklavik
# Processing Record 46 of Set 7 | sawtell
# Processing Record 47 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | puerto del rosario
# Processing Record 50 of Set 7 | avera
# Processing Record 1 of Set 8 | estevan
# Processing Record 2 of Set 8 | nam phong
# Processing Record 3 of Set 8 | hamilton
# Processing Record 4 of Set 8 | unnao
# Processing Record 5 of Set 8 | tir pol
# City not found. Skipping...
# Processing Record 6 of Set 8 | nyaunglebin
# Processing Record 7 of Set 8 | dzerzhinskoye
# Processing Record 8 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 8 | krasnyy yar
# Processing Record 10 of Set 8 | serenje
# Processing Record 11 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 8 | nabire
# Processing Record 13 of Set 8 | pudozh
# Processing Record 14 of Set 8 | nijar
# Processing Record 15 of Set 8 | sharjah
# Processing Record 16 of Set 8 | joshimath
# Processing Record 17 of Set 8 | shahrud
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | olafsvik
# Processing Record 21 of Set 8 | keffi
# Processing Record 22 of Set 8 | half moon bay
# Processing Record 23 of Set 8 | bambous virieux
# Processing Record 24 of Set 8 | whitehorse
# Processing Record 25 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 8 | kuytun
# Processing Record 27 of Set 8 | lloydminster
# Processing Record 28 of Set 8 | alekseyevka
# Processing Record 29 of Set 8 | anqing
# Processing Record 30 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 31 of Set 8 | beira
# Processing Record 32 of Set 8 | middleton
# Processing Record 33 of Set 8 | canarana
# Processing Record 34 of Set 8 | charlestown
# Processing Record 35 of Set 8 | sal rei
# Processing Record 36 of Set 8 | sorland
# Processing Record 37 of Set 8 | port-gentil
# Processing Record 38 of Set 8 | pasni
# Processing Record 39 of Set 8 | rockingham
# Processing Record 40 of Set 8 | boende
# Processing Record 41 of Set 8 | vegreville
# Processing Record 42 of Set 8 | mizan teferi
# Processing Record 43 of Set 8 | muhos
# Processing Record 44 of Set 8 | buala
# Processing Record 45 of Set 8 | tocopilla
# Processing Record 46 of Set 8 | port pirie
# Processing Record 47 of Set 8 | curaca
# Processing Record 48 of Set 8 | souillac
# Processing Record 49 of Set 8 | tomatlan
# Processing Record 50 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 9 | ossora
# Processing Record 2 of Set 9 | omutinskoye
# City not found. Skipping...
# Processing Record 3 of Set 9 | erenhot
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | labuhan
# Processing Record 6 of Set 9 | liusha
# Processing Record 7 of Set 9 | valparaiso
# Processing Record 8 of Set 9 | teberda
# Processing Record 9 of Set 9 | yeniseysk
# Processing Record 10 of Set 9 | cairns
# Processing Record 11 of Set 9 | beruwala
# Processing Record 12 of Set 9 | stromness
# Processing Record 13 of Set 9 | arvika
# Processing Record 14 of Set 9 | hluti
# Processing Record 15 of Set 9 | los llanos de aridane
# Processing Record 16 of Set 9 | black forest
# Processing Record 17 of Set 9 | bud
# Processing Record 18 of Set 9 | hibbing
# Processing Record 19 of Set 9 | arman
# Processing Record 20 of Set 9 | okato
# Processing Record 21 of Set 9 | cochabamba
# Processing Record 22 of Set 9 | hualmay
# Processing Record 23 of Set 9 | flinders
# Processing Record 24 of Set 9 | harper
# Processing Record 25 of Set 9 | rawlins
# Processing Record 26 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 9 | evanston
# Processing Record 28 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 9 | abramovka
# Processing Record 30 of Set 9 | huajuapan
# City not found. Skipping...
# Processing Record 31 of Set 9 | sitka
# Processing Record 32 of Set 9 | langfang
# Processing Record 33 of Set 9 | isangel
# Processing Record 34 of Set 9 | chimala
# Processing Record 35 of Set 9 | whitewater
# Processing Record 36 of Set 9 | moyamba
# Processing Record 37 of Set 9 | mason city
# Processing Record 38 of Set 9 | belmonte
# Processing Record 39 of Set 9 | saint-georges
# Processing Record 40 of Set 9 | grafton
# Processing Record 41 of Set 9 | huilong
# Processing Record 42 of Set 9 | caxito
# Processing Record 43 of Set 9 | winneba
# Processing Record 44 of Set 9 | yuncheng
# Processing Record 45 of Set 9 | haines junction
# Processing Record 46 of Set 9 | sunyani
# Processing Record 47 of Set 9 | san cristobal
# Processing Record 48 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 9 | kita
# Processing Record 50 of Set 9 | sholokhove
# Processing Record 1 of Set 10 | kichera
# Processing Record 2 of Set 10 | opuwo
# Processing Record 3 of Set 10 | salvador
# Processing Record 4 of Set 10 | sao desiderio
# Processing Record 5 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 6 of Set 10 | clarence town
# Processing Record 7 of Set 10 | quatre cocos
# Processing Record 8 of Set 10 | townsville
# Processing Record 9 of Set 10 | xiaoweizhai
# Processing Record 10 of Set 10 | tambacounda
# Processing Record 11 of Set 10 | rawson
# Processing Record 12 of Set 10 | bonthe
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | puerto penasco
# Processing Record 16 of Set 10 | yazman
# Processing Record 17 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 10 | visby
# Processing Record 19 of Set 10 | mareeba
# Processing Record 20 of Set 10 | bella union
# Processing Record 21 of Set 10 | changanacheri
# Processing Record 22 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 10 | tiassale
# Processing Record 24 of Set 10 | cohoes
# Processing Record 25 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 10 | progreso
# Processing Record 27 of Set 10 | iracoubo
# Processing Record 28 of Set 10 | mount gambier
# Processing Record 29 of Set 10 | sikea
# City not found. Skipping...
# Processing Record 30 of Set 10 | yenagoa
# Processing Record 31 of Set 10 | payson
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | lebedinyy
# Processing Record 34 of Set 10 | tigre
# Processing Record 35 of Set 10 | songea
# Processing Record 36 of Set 10 | nhulunbuy
# Processing Record 37 of Set 10 | nioro
# Processing Record 38 of Set 10 | ust-tsilma
# Processing Record 39 of Set 10 | jiuquan
# Processing Record 40 of Set 10 | eenhana
# Processing Record 41 of Set 10 | meulaboh
# Processing Record 42 of Set 10 | nanae
# Processing Record 43 of Set 10 | sumkino
# Processing Record 44 of Set 10 | ahipara
# Processing Record 45 of Set 10 | batsfjord
# Processing Record 46 of Set 10 | svetlyy
# Processing Record 47 of Set 10 | eunice
# Processing Record 48 of Set 10 | chimoio
# Processing Record 49 of Set 10 | roma
# Processing Record 50 of Set 10 | ponta do sol
# Processing Record 1 of Set 11 | suluq
# Processing Record 2 of Set 11 | mildura
# Processing Record 3 of Set 11 | bonavista
# Processing Record 4 of Set 11 | klaksvik
# Processing Record 5 of Set 11 | lorengau
# Processing Record 6 of Set 11 | gizo
# Processing Record 7 of Set 11 | garowe
# Processing Record 8 of Set 11 | ferme-neuve
# Processing Record 9 of Set 11 | vestmanna
# Processing Record 10 of Set 11 | movilita
# Processing Record 11 of Set 11 | sudzha
# Processing Record 12 of Set 11 | aransas pass
# Processing Record 13 of Set 11 | aklera
# Processing Record 14 of Set 11 | ibra
# Processing Record 15 of Set 11 | maceio
# Processing Record 16 of Set 11 | tubuala
# Processing Record 17 of Set 11 | houston
# Processing Record 18 of Set 11 | fukue
# Processing Record 19 of Set 11 | tibiri
# Processing Record 20 of Set 11 | shinshiro
# Processing Record 21 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 11 | along
# Processing Record 23 of Set 11 | reconquista
# Processing Record 24 of Set 11 | bridlington
# Processing Record 25 of Set 11 | nicolas bravo
# Processing Record 26 of Set 11 | sabile
# Processing Record 27 of Set 11 | kainantu
# Processing Record 28 of Set 11 | grand gaube
# Processing Record 29 of Set 11 | lamar
# Processing Record 30 of Set 11 | yerbogachen
# Processing Record 31 of Set 11 | kemijarvi
# Processing Record 32 of Set 11 | elliot
# Processing Record 33 of Set 11 | tommot
# Processing Record 34 of Set 11 | svelgen
# Processing Record 35 of Set 11 | sungairaya
# Processing Record 36 of Set 11 | xingyi
# Processing Record 37 of Set 11 | derbent
# Processing Record 38 of Set 11 | port hawkesbury
# Processing Record 39 of Set 11 | itoman
# Processing Record 40 of Set 11 | sabha
# Processing Record 41 of Set 11 | stettler
# Processing Record 42 of Set 11 | omboue
# Processing Record 43 of Set 11 | grajau
# Processing Record 44 of Set 11 | broken hill
# Processing Record 45 of Set 11 | acarau
# Processing Record 46 of Set 11 | yantarnyy
# Processing Record 47 of Set 11 | isabela
# Processing Record 48 of Set 11 | kalaleh
# Processing Record 49 of Set 11 | eyl
# Processing Record 50 of Set 11 | czarnkow
# Processing Record 1 of Set 12 | mogadishu
# Processing Record 2 of Set 12 | the pas
# Processing Record 3 of Set 12 | san quintin
# Processing Record 4 of Set 12 | cortez
# Processing Record 5 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 6 of Set 12 | tual
# Processing Record 7 of Set 12 | baryatino
# Processing Record 8 of Set 12 | chone
# Processing Record 9 of Set 12 | kendrapara
# Processing Record 10 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 12 | san carlos de bariloche
# Processing Record 12 of Set 12 | ghanzi
# Processing Record 13 of Set 12 | shetpe
# Processing Record 14 of Set 12 | manggar
# Processing Record 15 of Set 12 | pangody
# Processing Record 16 of Set 12 | martinho campos
# Processing Record 17 of Set 12 | kurduvadi
# Processing Record 18 of Set 12 | altamira
# Processing Record 19 of Set 12 | moindou
# Processing Record 20 of Set 12 | halvad
# Processing Record 21 of Set 12 | pouso alegre
# Processing Record 22 of Set 12 | konce
# Processing Record 23 of Set 12 | pochutla
# Processing Record 24 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 25 of Set 12 | yantal
# Processing Record 26 of Set 12 | laguna
# Processing Record 27 of Set 12 | cassilandia
# Processing Record 28 of Set 12 | usinsk
# Processing Record 29 of Set 12 | pitimbu
# Processing Record 30 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | kostomuksha
# Processing Record 32 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 12 | rieti
# Processing Record 34 of Set 12 | gamba
# Processing Record 35 of Set 12 | beni
# Processing Record 36 of Set 12 | healdsburg
# Processing Record 37 of Set 12 | baykit
# Processing Record 38 of Set 12 | poum
# Processing Record 39 of Set 12 | clermont
# Processing Record 40 of Set 12 | oil city
# Processing Record 41 of Set 12 | noshiro
# Processing Record 42 of Set 12 | qatana
# Processing Record 43 of Set 12 | bendigo
# Processing Record 44 of Set 12 | awjilah
# Processing Record 45 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | ola
# Processing Record 47 of Set 12 | slantsy
# Processing Record 48 of Set 12 | qui nhon
# Processing Record 49 of Set 12 | okhotsk
# Processing Record 50 of Set 12 | batatais
# Processing Record 1 of Set 13 | lavrentiya
# Processing Record 2 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 13 | sao sebastiao do passe
# Processing Record 4 of Set 13 | saint-francois
# Processing Record 5 of Set 13 | tignere
# Processing Record 6 of Set 13 | mandurah
# Processing Record 7 of Set 13 | dwarka
# Processing Record 8 of Set 13 | san policarpo
# Processing Record 9 of Set 13 | dali
# Processing Record 10 of Set 13 | lydenburg
# Processing Record 11 of Set 13 | horasan
# Processing Record 12 of Set 13 | hendijan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 562

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Upernavik  72.79  -56.15      9.93        94          77        3.56
# 1       Khash  28.22   61.22     55.38        29           0        5.75
# 2   Quelimane -17.88   36.89     87.01        66           0       16.11
# 3  Kaitangata -46.28  169.85     48.99        96         100        1.99
# 4   Namatanai  -3.67  152.43     80.55        79          96        5.59
# 5   Abu Dhabi  24.47   54.37     84.20        51           0        8.05
# 6    Hermanus -34.42   19.23     66.99        79          40        5.01
# 7      Hobart -42.88  147.33     53.60        58          75       11.41
# 8        Umea  63.83   20.26     46.40        59           0       21.92
# 9   Ilulissat  69.22  -51.10     21.20        67          75       12.75
#
#   Country                 Date
# 0      GL  2020-11-05 15:16:46
# 1      IR  2020-11-05 15:16:46
# 2      MZ  2020-11-05 15:16:46
# 3      NZ  2020-11-05 15:16:46
# 4      PG  2020-11-05 15:16:46
# 5      AE  2020-11-05 15:14:20
# 6      ZA  2020-11-05 15:13:24
# 7      AU  2020-11-05 15:12:06
# 8      SE  2020-11-05 15:16:47
# 9      GL  2020-11-05 15:16:47

# %%
new_column_order = ["City","Country","Date","Lat", "Lng", "Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0        Upernavik      GL  2020-11-05 15:16:46  72.79  -56.15      9.93
# 1            Khash      IR  2020-11-05 15:16:46  28.22   61.22     55.38
# 2        Quelimane      MZ  2020-11-05 15:16:46 -17.88   36.89     87.01
# 3       Kaitangata      NZ  2020-11-05 15:16:46 -46.28  169.85     48.99
# 4        Namatanai      PG  2020-11-05 15:16:46  -3.67  152.43     80.55
# ..             ...     ...                  ...    ...     ...       ...
# 557         Dwarka      IN  2020-11-05 15:18:27  22.24   68.97     81.72
# 558  San Policarpo      PH  2020-11-05 15:18:27  12.18  125.51     79.75
# 559           Dali      CN  2020-11-05 15:18:27  25.70  100.18     55.27
# 560      Lydenburg      ZA  2020-11-05 15:18:27 -25.10   30.46     75.99
# 561        Horasan      TR  2020-11-05 15:18:27  40.05   42.17     53.11
#
#      Humidity  Cloudiness  Wind Speed
# 0          94          77        3.56
# 1          29           0        5.75
# 2          66           0       16.11
# 3          96         100        1.99
# 4          79          96        5.59
# ..        ...         ...         ...
# 557        56           0        7.92
# 558        83          11        4.92
# 559        85           1        4.81
# 560        56         100        4.00
# 561        63         100        4.65
#
# [562 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '11/05/20'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-c1aba8d881f4> in <module>
#      12
#      13 # Save the figure.
# ---> 14 plt.savefig("weather_data/Fig1.png")
#      15
#      16 # Show plot.
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/Fig1.png'

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-576cacec601e> in <module>
#      11 plt.grid(True)
#      12 # Save the figure.
# ---> 13 plt.savefig("weather_data/Fig2.png")
#      14 # Show plot.
#      15 plt.show()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/Fig2.png'

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-c2dc6bdc83cb> in <module>
#      11 plt.grid(True)
#      12 # Save the figure.
# ---> 13 plt.savefig("weather_data/Fig4.png")
#      14 # Show plot.
#      15 plt.show()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/Fig4.png'

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a415911b13a5> in <module>
#       1 # Perform linear regression.
# ----> 2 (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#       3
#       4 # Calculate the regression line "y values" from the slope and intercept.
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'x_values' is not defined

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                        Tacna
# Lat                        -18.01
# Lng                        -70.25
# Max Temp                     66.2
# Humidity                       68
# Cloudiness                      0
# Wind Speed                   6.93
# Country                        PE
# Date          2020-11-05 15:16:48
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n % Humidity', 
                       '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,"test", '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'test', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'test', 'Wind Speed',(40,35))
