# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")

vacation_df.head(30)
# Out:
#     City_ID            City Country  Max Temp Current Description    Lat  \
# 0         2         Isangel      VU     77.00           clear sky -19.55
# 1        22        Ko Samui      TH     82.69           clear sky   9.54
# 2        24           Jesup      US     77.00           clear sky  31.61
# 3        39      Georgetown      MY     80.60          light rain   5.41
# 4        41       Toamasina      MG     77.00         shower rain -18.17
# 5        45        Acapulco      MX     80.60    scattered clouds  16.86
# 6        46           Altar      MX     83.77     overcast clouds  30.70
# 7        49    Port Hedland      AU     80.60           clear sky -20.32
# 8        53          Noumea      NC     78.01           clear sky -22.28
# 9        54      Nouadhibou      MR     84.20     overcast clouds  20.93
# 10       59         Kavieng      PG     82.38          few clouds  -2.57
# 11       63          Atuona      PF     77.81       broken clouds  -9.80
# 12       75            Poum      NC     77.47           clear sky -20.23
# 13       76    General Pico      AR     79.97          light rain -35.66
# 14       78      Sao Mateus      BR     81.68          light rain -18.72
# 15       81         Penalva      BR     85.75     overcast clouds  -3.29
# 16       85           Arlit      NE     88.63           clear sky  18.74
# 17       86          Ranong      TH     77.92    scattered clouds   9.97
# 18       92            Tuni      IN     76.35           clear sky  17.35
# 19      104        Progreso      MX     82.00       broken clouds  21.28
# 20      106      Gualaquiza      EC     83.30          light rain  -3.40
# 21      107           Paita      PE     75.20          few clouds  -5.09
# 22      112          Faanui      PF     79.65          light rain -16.48
# 23      113           Guane      CU     81.61     overcast clouds  22.20
# 24      115         Biltine      TD     86.56           clear sky  14.53
# 25      117         Bubaque      GW     84.24           clear sky  11.28
# 26      119        Kirakira      SB     79.14       moderate rain -10.45
# 27      129  Chettipalaiyam      IN     78.80                haze  10.90
# 28      130     Constantine      DZ     80.60    scattered clouds  36.37
# 29      142        Victoria      HK     79.00          light rain  22.29
#
#        Lng                                   Hotel Name
# 0   169.27                  Volcano Sea View Tree House
# 1    99.94  The Passage Samui Villas & Resort, Thailand
# 2   -81.89                                Western Motel
# 3   100.34                               Cititel Penang
# 4    49.38                                     Hotel H1
# 5   -99.89                    HS Hotsson Smart Acapulco
# 6  -111.82                            Hotel Maria Elena
# 7   118.57                          The Esplanade Hotel
# 8   166.46                               Hôtel Le Lagon
# 9   -17.03                                    El Medina
# 10  150.80                          Nusa Island Retreat
# 11 -139.03                                  Villa Enata
# 12  164.02                                  Gîte kajeon
# 13  -63.76                               Hotel Malargue
# 14  -39.86                              Hotel Rio Norte
# 15  -45.17                                HOTEL MELONIO
# 16    7.39                         Hôtel Telwa Bungalow
# 17   98.63                         Tinidee Hotel@Ranong
# 18   82.55                            Sai Krishna Lodge
# 19  -89.67                            Playa Linda Hotel
# 20  -78.55                             Hotel Merceditas
# 21  -81.11                       Hotel Náutico de Paita
# 22 -151.75           Bora-Bora Pearl Beach Resort & Spa
# 23  -84.09        base de Campismo LosPortales de Guane
# 24   20.92               Hôtel Trois Étoiles de Biltine
# 25  -15.83                           Casa Dora, Bubaque
# 26  161.92                                 SanBiz Lodge
# 27   77.07                        PVS தில்லையம்மன் லாரி
# 28    6.61                            Grand Hotel Cirta
# 29  114.16                           Mini Hotel Central

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country Code</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Maximum Temperature</dt><dd>{Max Temp}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Mount Pleasant"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Mount Pleasant"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Marana"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "San Patricio"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Mocorito"]

# %%
vacation_start
# Out:
#      City_ID            City Country  Max Temp Current Description    Lat  \
# 172      625  Mount Pleasant      US     75.99          few clouds  32.79
#
#        Lng                   Hotel Name
# 172 -79.86  Best Western Patriots Point

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[['Lat','Lng']].to_numpy().tolist()
end = vacation_start[['Lat','Lng']].to_numpy().tolist()
stop1 = vacation_stop1[['Lat','Lng']].to_numpy().tolist()
stop2 = vacation_stop2[['Lat','Lng']].to_numpy().tolist()
stop3 = vacation_stop3[['Lat','Lng']].to_numpy().tolist()

print(start)
# Out:
# [[32.79, -79.86]]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
start2end = gmaps.directions_layer(start[0], stop1[0],waypoints=[stop1[0],stop2[0],stop3[0],end[0]],travel_mode='DRIVING')
fig.add_layer(start2end)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description    Lat  \
# 0      625  Mount Pleasant      US     75.99          few clouds  32.79
# 1      471          Marana      US     82.40           clear sky  32.44
# 2      150    San Patricio      US     77.00          few clouds  28.02
# 3      615        Mocorito      MX     83.82           clear sky  25.48
#
#       Lng                               Hotel Name
# 0  -79.86              Best Western Patriots Point
# 1 -111.23  Valley of the Sun Mobile Home & RV Park
# 2  -97.52                       Motel 6 Sinton, TX
# 3 -107.92                    Casa de Don Eustaquio

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country Code</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Maximum Temperature</dt><dd>{Max Temp}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
